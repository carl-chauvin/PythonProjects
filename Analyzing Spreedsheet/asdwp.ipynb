# %%
pip install openpyxl
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
df_facilities = pd.read_excel('./Airport_Data.xlsx', sheet_name='Facilities')

# %%
df_facilities
# Out:
#      SiteNumber           Type LocationID EffectiveDate Region DistrictOffice  \
# 0      50009.*A        AIRPORT       'ADK     3/30/2017    AAL           NONE
# 1     50016.1*A        AIRPORT       'AKK     3/30/2017    AAL           NONE
# 2      50017.*A        AIRPORT       'Z13     3/30/2017    AAL           NONE
# 3     50017.1*C  SEAPLANE BASE       'KKI     3/30/2017    AAL           NONE
# 4      50020.*A        AIRPORT       'AKI     3/30/2017    AAL           NONE
# ..          ...            ...        ...           ...    ...            ...
# 746  50920.12*C  SEAPLANE BASE       '2Y3     3/30/2017    AAL           NONE
# 747    50920.*A        AIRPORT       'YAK     3/30/2017    AAL           NONE
# 748   50925.1*A        AIRPORT       'A77     3/30/2017    AAL           NONE
# 749    50928.*C  SEAPLANE BASE       '78K     3/30/2017    AAL           NONE
# 750    50990.*A        AIRPORT       'L20     3/30/2017    AAL           NONE
#
# ...

# %%
df_facilities.head() #sirve para obtener las primeras filas(automaticamente leera las 5 primeras filas)
# Out:
#   SiteNumber           Type LocationID EffectiveDate Region DistrictOffice  \
# 0   50009.*A        AIRPORT       'ADK     3/30/2017    AAL           NONE
# 1  50016.1*A        AIRPORT       'AKK     3/30/2017    AAL           NONE
# 2   50017.*A        AIRPORT       'Z13     3/30/2017    AAL           NONE
# 3  50017.1*C  SEAPLANE BASE       'KKI     3/30/2017    AAL           NONE
# 4   50020.*A        AIRPORT       'AKI     3/30/2017    AAL           NONE
#
#   State StateName          County CountyState  ... AirportPositionSource  \
# 0    AK    ALASKA  ALEUTIANS WEST          AK  ...      3RD PARTY SURVEY
# 1    AK    ALASKA   KODIAK ISLAND          AK  ...                  NACO
# 2    AK    ALASKA          BETHEL          AK  ...                 STATE
# 3    AK    ALASKA          BETHEL          AK  ...                   NaN
# 4    AK    ALASKA          BETHEL          AK  ...                 STATE
#
# ...

# %%
df_facilities.loc()

# %%
df_facilities.tail() #sirve para leer las 5 ultimas filas
# Out:
#      SiteNumber           Type LocationID EffectiveDate Region DistrictOffice  \
# 746  50920.12*C  SEAPLANE BASE       '2Y3     3/30/2017    AAL           NONE
# 747    50920.*A        AIRPORT       'YAK     3/30/2017    AAL           NONE
# 748   50925.1*A        AIRPORT       'A77     3/30/2017    AAL           NONE
# 749    50928.*C  SEAPLANE BASE       '78K     3/30/2017    AAL           NONE
# 750    50990.*A        AIRPORT       'L20     3/30/2017    AAL           NONE
#
#     State StateName             County CountyState  ... AirportPositionSource  \
# 746    AK    ALASKA    SKAGWAY-YAKUTAT          AK  ...               FAA-EST
# 747    AK    ALASKA    SKAGWAY-YAKUTAT          AK  ...      3RD PARTY SURVEY
# 748    AK    ALASKA          KUSKOKWIM          AK  ...                   NaN
# 749    AK    ALASKA  KETCHIKAN GATEWAY          AK  ...                   NaN
# 750    AK    ALASKA        UPPER YUKON          AK  ...               FAA-EST
#
# ...

# %%
df_facilities.head(10)
# Out:
#    SiteNumber           Type LocationID EffectiveDate Region DistrictOffice  \
# 0    50009.*A        AIRPORT       'ADK     3/30/2017    AAL           NONE
# 1   50016.1*A        AIRPORT       'AKK     3/30/2017    AAL           NONE
# 2    50017.*A        AIRPORT       'Z13     3/30/2017    AAL           NONE
# 3   50017.1*C  SEAPLANE BASE       'KKI     3/30/2017    AAL           NONE
# 4    50020.*A        AIRPORT       'AKI     3/30/2017    AAL           NONE
# 5    50022.*C  SEAPLANE BASE       'KQA     3/30/2017    AAL           NONE
# 6   50022.1*A        AIRPORT       '7AK     3/30/2017    AAL           NONE
# 7   50024.1*A        AIRPORT       'AUK     3/30/2017    AAL           NONE
# 8  50027.52*C  SEAPLANE BASE       'Z33     3/30/2017    AAL           NONE
# 9  50027.53*A        AIRPORT       '5A8     3/30/2017    AAL           NONE
#
#   State StateName          County CountyState  ... AirportPositionSource  \
# ...

# %%
df_facilities.tail(100)
# Out:
#      SiteNumber           Type LocationID EffectiveDate Region DistrictOffice  \
# 651  50870.73*A        AIRPORT      'AK85     3/30/2017    AAL           NONE
# 652   50870.6*C  SEAPLANE BASE       'D75     3/30/2017    AAL           NONE
# 653  50870.25*A        AIRPORT      '71AK     3/30/2017    AAL           NONE
# 654  50870.22*A        AIRPORT      '3AK8     3/30/2017    AAL           NONE
# 655  50870.74*H       HELIPORT      '60AK     3/30/2017    AAL           NONE
# ..          ...            ...        ...           ...    ...            ...
# 746  50920.12*C  SEAPLANE BASE       '2Y3     3/30/2017    AAL           NONE
# 747    50920.*A        AIRPORT       'YAK     3/30/2017    AAL           NONE
# 748   50925.1*A        AIRPORT       'A77     3/30/2017    AAL           NONE
# 749    50928.*C  SEAPLANE BASE       '78K     3/30/2017    AAL           NONE
# 750    50990.*A        AIRPORT       'L20     3/30/2017    AAL           NONE
#
# ...

# %%
df_facilities.shape #para saber cuantas filas y columnas contiene el DF
# Out:
# (751, 103)

# %%
df_facilities['Type'].head(10) #devuelve las 10 primeras filas de la columna Type
# Out:
# 0          AIRPORT
# 1          AIRPORT
# 2          AIRPORT
# 3    SEAPLANE BASE
# 4          AIRPORT
# 5    SEAPLANE BASE
# 6          AIRPORT
# 7          AIRPORT
# 8    SEAPLANE BASE
# 9          AIRPORT
# Name: Type, dtype: object

# %%
df_facilities['Type'].head(10)
# Out:
# 0          AIRPORT
# 1          AIRPORT
# 2          AIRPORT
# 3    SEAPLANE BASE
# 4          AIRPORT
# 5    SEAPLANE BASE
# 6          AIRPORT
# 7          AIRPORT
# 8    SEAPLANE BASE
# 9          AIRPORT
# Name: Type, dtype: object

# %%
#para mostrar hasta 50 filas al imprimir un DataFrame o Serie. 
# #Si el objeto tiene más filas, se resumen mostrando solo las primeras y últimas filas.
pd.set_option('display.max_rows', 50)
df_facilities
# Out:
#      SiteNumber           Type LocationID EffectiveDate Region DistrictOffice  \
# 0      50009.*A        AIRPORT       'ADK     3/30/2017    AAL           NONE
# 1     50016.1*A        AIRPORT       'AKK     3/30/2017    AAL           NONE
# 2      50017.*A        AIRPORT       'Z13     3/30/2017    AAL           NONE
# 3     50017.1*C  SEAPLANE BASE       'KKI     3/30/2017    AAL           NONE
# 4      50020.*A        AIRPORT       'AKI     3/30/2017    AAL           NONE
# ..          ...            ...        ...           ...    ...            ...
# 746  50920.12*C  SEAPLANE BASE       '2Y3     3/30/2017    AAL           NONE
# 747    50920.*A        AIRPORT       'YAK     3/30/2017    AAL           NONE
# 748   50925.1*A        AIRPORT       'A77     3/30/2017    AAL           NONE
# 749    50928.*C  SEAPLANE BASE       '78K     3/30/2017    AAL           NONE
# 750    50990.*A        AIRPORT       'L20     3/30/2017    AAL           NONE
#
# ...

# %%
#Devuelve un arreglo con los valores únicos presentes en la columna Type del df.
df_facilities["Type"].unique()
# Out:
# array(['AIRPORT', 'SEAPLANE BASE', 'HELIPORT'], dtype=object)

# %%
#muestra los tipos de datos (como int64, float64, object, etc.) de cada columna del DataFrame
df_facilities.dtypes
# Out:
# SiteNumber          object
# Type                object
# LocationID          object
# EffectiveDate       object
# Region              object
#                      ...
# TransientStorage    object
# OtherServices       object
# WindIndicator       object
# IcaoIdentifier      object
# BeaconSchedule2     object
# Length: 103, dtype: object

# %%
#crea una Serie booleana donde cada valor es True si el valor en la columna #
# 'Type' es igual a 'Airport', y False en caso contrario.
df_facilities['Type']==  'SEAPLANE BASE' #'Airport'
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4      False
#        ...
# 746     True
# 747    False
# 748    False
# 749     True
# 750    False
# Name: Type, Length: 751, dtype: bool

# %%
#filtra el df y devuelve solo las filas donde la columna "Type" tiene el valor "SEAPLANE BASE".
df_facilities[df_facilities["Type"] == "SEAPLANE BASE"]
# Out:
#      SiteNumber           Type LocationID EffectiveDate Region DistrictOffice  \
# 3     50017.1*C  SEAPLANE BASE       'KKI     3/30/2017    AAL           NONE
# 5      50022.*C  SEAPLANE BASE       'KQA     3/30/2017    AAL           NONE
# 8    50027.52*C  SEAPLANE BASE       'Z33     3/30/2017    AAL           NONE
# 15    50031.5*C  SEAPLANE BASE      'AK81     3/30/2017    AAL           NONE
# 24    50035.2*C  SEAPLANE BASE       '3C3     3/30/2017    AAL           NONE
# ..          ...            ...        ...           ...    ...            ...
# 725  50877.32*C  SEAPLANE BASE       'MFN     3/30/2017    AAL           NONE
# 734  50877.01*C  SEAPLANE BASE       '2X2     3/30/2017    AAL           NONE
# 737    50905.*C  SEAPLANE BASE       '68A     3/30/2017    AAL           NONE
# 746  50920.12*C  SEAPLANE BASE       '2Y3     3/30/2017    AAL           NONE
# 749    50928.*C  SEAPLANE BASE       '78K     3/30/2017    AAL           NONE
#
# ...

# %%
#ordena el df en función de la columna "ARPElevation", en orden descendente (ascending=False). 
#Devuelve un nuevo DataFrame con las filas reordenadas.
df_facilities.sort_values(by = "ARPElevation", ascending = False)
# Out:
#      SiteNumber           Type LocationID EffectiveDate Region DistrictOffice  \
# 584   50739.1*A        AIRPORT      'AA09     3/30/2017    AAL           NONE
# 630  50738.20*A        AIRPORT      '93AK     3/30/2017    AAL           NONE
# 265   50324.6*A        AIRPORT       '4Z5     3/30/2017    AAL           NONE
# 582  50738.01*A        AIRPORT      '2AK7     3/30/2017    AAL           NONE
# 353  50439.18*A        AIRPORT      'AK80     3/30/2017    AAL           NONE
# ..          ...            ...        ...           ...    ...            ...
# 749    50928.*C  SEAPLANE BASE       '78K     3/30/2017    AAL           NONE
# 261    50321.*C  SEAPLANE BASE       'OOH     3/30/2017    AAL           NONE
# 289  50385.06*H       HELIPORT      '73AK     3/30/2017    AAL           NONE
# 714   50873.3*C  SEAPLANE BASE       'KWP     3/30/2017    AAL           NONE
# 713    50872.*C  SEAPLANE BASE       'KWF     3/30/2017    AAL           NONE
#
# ...

# %%
df_facilities.describe()
# Out:
#        ARPElevation  MagneticVariationYear  TrafficPatternAltitude  \
# count    751.000000             615.000000               13.000000
# mean     425.932091            1993.744715              984.538462
# std      657.117067              11.635403              447.404481
# min        0.000000            1965.000000              560.000000
# 25%       45.000000            1985.000000              600.000000
# 50%      170.000000            1985.000000              800.000000
# 75%      440.000000            2005.000000             1100.000000
# max     3984.000000            2020.000000             2078.000000
#
#        DistanceFromCBD  LandAreaCoveredByAirport  LastInspectionDate  \
# count       742.000000                241.000000        5.140000e+02
# mean          5.109164                429.128631        6.675374e+06
# std          10.304681                969.927770        1.804434e+06
# min           0.000000                  1.000000        1.031984e+06
# ...

# %%
df_facilities["ARPElevation"].mean()
# Out:
# np.float64(425.93209054593876)

# %%
df_facilities["ARPElevation"].max()
# Out:
# np.int64(3984)

# %%
df_facilities["ARPElevation"].min()
# Out:
# np.int64(0)

# %%
df_seaplane = df_facilities[df_facilities["Type"] == "SEAPLANE BASE"]

# %%
#exporta el DataFrame df_seaplane a un archivo de Excel llamado seaplane.xlsx 
#guardado en el directorio "./"
df_seaplane.to_excel("./seaplane.xlsx")
