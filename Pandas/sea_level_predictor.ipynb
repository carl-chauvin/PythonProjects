# %% [markdown]
# <h2>Predictor Del Nivel Del Mar</h2>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import linregress

def draw_plot():
    # Read data from file
    df = pd.read_csv('ExcelFiles/epa-sea-level.csv')

    # Create scatter plot
    #fig, ax = plt.subplots(figsize=(10,6))
    #df.plot(kind='scatter', x='Year', y='CSIRO Adjusted Sea Level', alpha=0.5)

    plt.scatter(df['Year'], df['CSIRO Adjusted Sea Level'], color='green', alpha=0.5)

    # Create first line of best fit
    slope, intercept, _, _, _ = linregress(df['Year'], df['CSIRO Adjusted Sea Level'])
    years_extended = pd.Series(range(1880, 2051))
    sea_level_predicted = slope + intercept * years_extended
    plt.plot(years_extended, sea_level_predicted, color='red')


    # Create second line of best fit
    df_y2000 = (df['Year'] >= 2000)
    slope, intercept, _, _, _ = linregress(df_y2000, df['CSIRO Adjusted Sea Level'])
    years_extended2 = pd.Series(range(2000, 2051))
    sea_level_predicted2 = slope + intercept * years_extended2

    plt.plot(years_extended2, sea_level_predicted2, color='yellow')

    # Add labels and title
    plt.title('Rise in Sea Level')
    plt.xlabel('Year')
    plt.ylabel('Sea Level (inches)')
    
    # Save plot and return data for testing (DO NOT MODIFY)
    #plt.savefig('sea_level_plot.png')
    #return plt.gca()

draw_plot()

# %%
slope, intercept, _, _, _ = linregress(df['Year'], df['CSIRO Adjusted Sea Level'])

    
    # Crear una serie de años extendidos hasta 2050
years_extended = pd.Series(range(df['Year'].min(), 2051))
    
    # Calcular el nivel del mar predicho para cada año
sea_level_predicted = intercept + slope * years_extended

    # Dibujar la línea de mejor ajuste
plt.plot(years_extended, sea_level_predicted, color='red', label='Best Fit Line (All Data)')

    # Configuración del gráfico
plt.title('Sea Level Rise Prediction')
plt.xlabel('Year')
plt.ylabel('CSIRO Adjusted Sea Level (inches)')
plt.legend()

    # Mostrar el gráfico
plt.show()

# %%
df = pd.read_csv('ExcelFiles/epa-sea-level.csv')
fig, ax = plt.subplots(figsize=(10,6))
df.plot(kind='scatter', x='Year', y='CSIRO Adjusted Sea Level', ax=ax)
plt.show()
